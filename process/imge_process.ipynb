# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %%
img = plt.imread("../images/marguerite.jpg")
img.shape
# Out:
# (340, 522, 3)

# %%
plt.imshow(img)

# %%
img_r = img[:,:,:1]

# %%
img_r.shape
# Out:
# (340, 522, 1)

# %%
plt.imshow(img_r)

# %%
img_g = img[:,:,1:2]

# %%
img_g.shape
# Out:
# (340, 522, 1)

# %%
plt.imshow(img_g)

# %%
img_b = img[:,:,2:3]
plt.imshow(img_b)

# %%
img_r_norm = img_r/255
img_r_norm
# Out:
# array([[[0.0745098 ],
#         [0.0745098 ],
#         [0.0745098 ],
#         ...,
#         [0.05882353],
#         [0.05882353],
#         [0.05882353]],
#
#        [[0.0745098 ],
#         [0.0745098 ],
#         [0.0745098 ],
#         ...,
#         [0.05882353],
#         [0.05882353],
#         [0.05882353]],
#
#        [[0.0745098 ],
#         [0.0745098 ],
#         [0.0745098 ],
#         ...,
#         [0.0627451 ],
#         [0.0627451 ],
#         [0.0627451 ]],
#
#        ...,
#
#        [[0.15294118],
#         [0.15294118],
#         [0.14901961],
#         ...,
#         [0.0627451 ],
#         [0.0627451 ],
#         [0.0627451 ]],
#
#        [[0.15294118],
#         [0.15294118],
#         [0.14901961],
#         ...,
#         [0.0627451 ],
#         [0.0627451 ],
#         [0.0627451 ]],
#
#        [[0.15294118],
#         [0.15294118],
#         [0.14901961],
#         ...,
#         [0.0627451 ],
#         [0.0627451 ],
#         [0.0627451 ]]])

# %%
arr = np.array(img_r)
shape = arr.shape

# %%
flat_arr = arr.ravel()
flat_arr
# Out:
# array([19, 19, 19, ..., 16, 16, 16], dtype=uint8)

# %%
vector = np.matrix(flat_arr)

# %%
vector
# Out:
# matrix([[19, 19, 19, ..., 16, 16, 16]], dtype=uint8)

# %%
arr2 = np.asarray(vector).reshape(shape)
plt.imshow(arr2)

# %%
def imgToArr(path):
    img = plt.imread(path)
    arr = np.array(img)
    flat_arr = arr.ravel()
    return flat_arr

# %%
imgPath = "../images/marguerite.jpg"
imgToArr(imgPath)
# Out:
# array([19, 24, 54, ..., 16, 28, 54], dtype=uint8)
